# %%
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.basemap import Basemap
from sklearn.model_selection import TimeSeriesSplit
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## To be used for Capstone Project

# %%
print('HELLO CAPSTONE PROJECT!!')
# Out:
# HELLO CAPSTONE PROJECT!!

# %%
accidents = pd.read_csv('C:/Users/PAPIRO/Documents/Documentos Antonio/Data Science IBM/Curso9_Applied Data Science Capstone/Accidents0515.csv',index_col='Accident_Index')
accidents.head(5)
# Out:
#                 Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# Accident_Index
# 200501BS00001                525680.0                178240.0  -0.191170
# 200501BS00002                524170.0                181650.0  -0.211708
# 200501BS00003                524520.0                182240.0  -0.206458
# 200501BS00004                526900.0                177530.0  -0.173862
# 200501BS00005                528060.0                179040.0  -0.156618
#
#                  Latitude  Police_Force  Accident_Severity  \
# Accident_Index
# 200501BS00001   51.489096             1                  2
# 200501BS00002   51.520075             1                  3
# 200501BS00003   51.525301             1                  3
# 200501BS00004   51.482442             1                  3
# 200501BS00005   51.495752             1                  3
#
#                 Number_of_Vehicles  Number_of_Casualties        Date  \
# Accident_Index
# ...

# %%
accidents['Accident_Severity'].describe().astype('int64')
# Out:
# count    1780653
# mean           2
# std            0
# min            1
# 25%            3
# 50%            3
# 75%            3
# max            3
# Name: Accident_Severity, dtype: int64

# %% [markdown]
# ## Problem description:
#
# In this job, a dataset of UK car accidents in period 2010-2015 is going to be used as a background to predict accident severity in another different country or city. The following methodology will be followed using CRISP-DM :
# a) Business understanding: To understand which variables are more influent to predict severity in a car accident, rated (1:Fatal; 2:Serious; 3:Slight).
# b) Data understanding: Source taken from Kagge (https://www.kaggle.com/silicon99/dft-accident-data). We will represent visually each factor vs. severity to check wether there is a corralation or not, using mathplot lib and seaborn package.
# c) Data preparation: Non relevant columns will be removed and data types will be checked to ensure consistency of model .
# d) Modeling: Several supervised machine learning models to be tested to choose the best fit with real data (SVM,Linear regression
# e) Evaluation: Accuracy of model to be calculated by F1-score, precision,jaccard score,...
# f) Deployment: Model prepared is going to be used as a background to predict severity rates in another country (to include link of dataset)
